# %%
import numpy as np

# %%
xy = np.loadtxt(fname='./wine-reviews/winemag-data_first150k.csv', delimiter=',', skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c302fc7e6819> in <module>()
# ----> 1 xy = np.loadtxt(fname='./wine-reviews/winemag-data_first150k.csv', delimiter=',', unpack=True , skiprows=1)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1099         # converting the data
#    1100         X = None
# -> 1101         for x in read_data(_loadtxt_chunksize):
#    1102             if X is None:
#    1103                 X = np.array(x, dtype)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
# ...
